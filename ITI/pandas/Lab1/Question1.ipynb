# %% [markdown]
# # Question1

# %%
import pandas as pd

# %%
import requests, json

# %%
import requests

url = "https://community-open-weather-map.p.rapidapi.com/climate/month"

querystring = {"q":"cairo"}

headers = {
    'x-rapidapi-host': "community-open-weather-map.p.rapidapi.com",
    'x-rapidapi-key': "c59918bb63msh3006759ebda7f12p15f0f5jsn1ef6b0ed2c71"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"cod":"200","city":{"id":360630,"name":"Cairo","coord":{"lon":31.2497,"lat":30.0626},"country":"EG"},"message":0.364331939,"list":[{"dt":1642118400,"humidity":59.9,"pressure":1017.75,"temp":{"average":287.12,"average_max":290.97,"average_min":283.11,"record_max":293.15,"record_min":277.8},"wind_speed":4.47},{"dt":1642204800,"humidity":63.27,"pressure":1019.25,"temp":{"average":286.89,"average_max":291.45,"average_min":282.65,"record_max":294.12,"record_min":276.99},"wind_speed":4.48},{"dt":1642291200,"humidity":57.76,"pressure":1017.88,"temp":{"average":286.19,"average_max":291.17,"average_min":281.83,"record_max":295,"record_min":276.32},"wind_speed":4.86},{"dt":1642377600,"humidity":60.96,"pressure":1017.27,"temp":{"average":286.6,"average_max":291.21,"average_min":281.4,"record_max":293.93,"record_min":275.03},"wind_speed":4.08},{"dt":1642464000,"humidity":59.32,"pressure":1018.62,"temp":{"average":286.67,"average_max":290.93,"average_min":281.7,"record_max":295.15,"record_min":274.36},"wind_speed":4.9},{"dt":1642550400,"humidity":63.17,"pressure":1019.84,"temp":{"average":286.26,"average_max":291.04,"average_min":281.27,"record_max":293.95,"record_min":274.57},"wind_speed":4.3},{"dt":1642636800,"humidity":58.39,"pressure":1021.31,"temp":{"average":286.25,"average_max":291.49,"average_min":281.48,"record_max":295,"record_min":275.24},"wind_speed":3.65},{"dt":1642723200,"humidity":54.07,"pressure":1020.47,"temp":{"average":287.23,"average_max":293.07,"average_min":281.59,"record_max":297.15,"record_min":276.61},"wind_speed":3.55},{"dt":1642809600,"humidity":53.7,"pressure":1018.68,"temp":{"average":287.9,"average_max":293.44,"average_min":282.56,"record_max":301.04,"record_min":276.06},"wind_speed":3.78},{"dt":1642896000,"humidity":55.81,"pressure":1017.87,"temp":{"average":287.7,"average_max":292.27,"average_min":282.73,"record_max":297.1,"record_min":277.64},"wind_speed":3.91},{"dt":1642982400,"humidity":56.6,"pressure":1017.74,"temp":{"average":288.09,"average_max":292.74,"average_min":283.38,"record_max":296.03,"record_min":277.36},"wind_speed":3.92},{"dt":1643068800,"humidity":57.74,"pressure":1018.05,"temp":{"average":287.92,"average_max":293,"average_min":282.2,"record_max":299.15,"record_min":275.7},"wind_speed":3.46},{"dt":1643155200,"humidity":54.63,"pressure":1017,"temp":{"average":287.86,"average_max":292.62,"average_min":282.61,"record_max":300.15,"record_min":273.39},"wind_speed":4.61},{"dt":1643241600,"humidity":56.83,"pressure":1016.67,"temp":{"average":287.38,"average_max":291.8,"average_min":282.34,"record_max":296,"record_min":278.65},"wind_speed":4.34},{"dt":1643328000,"humidity":55.14,"pressure":1018.82,"temp":{"average":286.77,"average_max":290.6,"average_min":282.86,"record_max":292.15,"record_min":277.33},"wind_speed":3.5},{"dt":1643414400,"humidity":56.1,"pressure":1020.11,"temp":{"average":286.63,"average_max":290.9,"average_min":282.2,"record_max":294.15,"record_min":276.37},"wind_speed":3.09},{"dt":1643500800,"humidity":54.62,"pressure":1020.15,"temp":{"average":286.64,"average_max":291.59,"average_min":281.83,"record_max":295.15,"record_min":276.68},"wind_speed":3.3},{"dt":1643587200,"humidity":54.55,"pressure":1019.76,"temp":{"average":286.93,"average_max":291.79,"average_min":282.1,"record_max":296.67,"record_min":276.41},"wind_speed":3.79},{"dt":1643673600,"humidity":58.68,"pressure":1019.31,"temp":{"average":287.57,"average_max":293.1,"average_min":282.31,"record_max":300.15,"record_min":277.07},"wind_speed":3.67},{"dt":1643760000,"humidity":61.32,"pressure":1018.99,"temp":{"average":287.91,"average_max":293.16,"average_min":282.9,"record_max":300.12,"record_min":276.49},"wind_speed":3.78},{"dt":1643846400,"humidity":59.98,"pressure":1019.63,"temp":{"average":287.58,"average_max":293.21,"average_min":282.47,"record_max":299.98,"record_min":276.6},"wind_speed":3.82},{"dt":1643932800,"humidity":58.14,"pressure":1018.92,"temp":{"average":287.99,"average_max":294.01,"average_min":282.33,"record_ ...

# %%
djson = json.loads(response.text)
djson['list']
# Out:
# [{'dt': 1642118400,
#   'humidity': 59.9,
#   'pressure': 1017.75,
#   'temp': {'average': 287.12,
#    'average_max': 290.97,
#    'average_min': 283.11,
#    'record_max': 293.15,
#    'record_min': 277.8},
#   'wind_speed': 4.47},
#  {'dt': 1642204800,
#   'humidity': 63.27,
#   'pressure': 1019.25,
#   'temp': {'average': 286.89,
#    'average_max': 291.45,
#    'average_min': 282.65,
#    'record_max': 294.12,
#    'record_min': 276.99},
#   'wind_speed': 4.48},
#  {'dt': 1642291200,
#   'humidity': 57.76,
#   'pressure': 1017.88,
#   'temp': {'average': 286.19,
#    'average_max': 291.17,
#    'average_min': 281.83,
#    'record_max': 295,
#    'record_min': 276.32},
#   'wind_speed': 4.86},
#  {'dt': 1642377600,
#   'humidity': 60.96,
#   'pressure': 1017.27,
#   'temp': {'average': 286.6,
#    'average_max': 291.21,
#    'average_min': 281.4,
#    'record_max': 293.93,
#    'record_min': 275.03},
#   'wind_speed': 4.08},
#  {'dt': 1642464000,
#   'humidity': 59.32,
#   'pressure': 1018.62,
#   'temp': {'average': 286.67,
#    'average_max': 290.93,
#    'average_min': 281.7,
#    'record_max': 295.15,
#    'record_min': 274.36},
#   'wind_speed': 4.9},
#  {'dt': 1642550400,
#   'humidity': 63.17,
#   'pressure': 1019.84,
#   'temp': {'average': 286.26,
#    'average_max': 291.04,
#    'average_min': 281.27,
#    'record_max': 293.95,
#    'record_min': 274.57},
#   'wind_speed': 4.3},
#  {'dt': 1642636800,
#   'humidity': 58.39,
#   'pressure': 1021.31,
#   'temp': {'average': 286.25,
#    'average_max': 291.49,
#    'average_min': 281.48,
#    'record_max': 295,
#    'record_min': 275.24},
#   'wind_speed': 3.65},
#  {'dt': 1642723200,
#   'humidity': 54.07,
#   'pressure': 1020.47,
#   'temp': {'average': 287.23,
#    'average_max': 293.07,
#    'average_min': 281.59,
#    'record_max': 297.15,
#    'record_min': 276.61},
#   'wind_speed': 3.55},
#  {'dt': 1642809600,
#   'humidity': 53.7,
#   'pressure': 1018.68,
#   'temp': {'average': 287.9,
#    'average_max': 293.44,
#    'average_min': 282.56,
#    'record_max': 301.04,
#    'record_min': 276.06},
#   'wind_speed': 3.78},
#  {'dt': 1642896000,
#   'humidity': 55.81,
#   'pressure': 1017.87,
#   'temp': {'average': 287.7,
#    'average_max': 292.27,
#    'average_min': 282.73,
#    'record_max': 297.1,
#    'record_min': 277.64},
#   'wind_speed': 3.91},
#  {'dt': 1642982400,
#   'humidity': 56.6,
#   'pressure': 1017.74,
#   'temp': {'average': 288.09,
#    'average_max': 292.74,
#    'average_min': 283.38,
#    'record_max': 296.03,
#    'record_min': 277.36},
#   'wind_speed': 3.92},
#  {'dt': 1643068800,
#   'humidity': 57.74,
#   'pressure': 1018.05,
#   'temp': {'average': 287.92,
#    'average_max': 293,
#    'average_min': 282.2,
#    'record_max': 299.15,
#    'record_min': 275.7},
#   'wind_speed': 3.46},
#  {'dt': 1643155200,
#   'humidity': 54.63,
#   'pressure': 1017,
#   'temp': {'average': 287.86,
#    'average_max': 292.62,
#    'average_min': 282.61,
#    'record_max': 300.15,
#    'record_min': 273.39},
#   'wind_speed': 4.61},
#  {'dt': 1643241600,
#   'humidity': 56.83,
#   'pressure': 1016.67,
#   'temp': {'average': 287.38,
#    'average_max': 291.8,
#    'average_min': 282.34,
#    'record_max': 296,
#    'record_min': 278.65},
#   'wind_speed': 4.34},
#  {'dt': 1643328000,
#   'humidity': 55.14,
#   'pressure': 1018.82,
#   'temp': {'average': 286.77,
#    'average_max': 290.6,
#    'average_min': 282.86,
#    'record_max': 292.15,
#    'record_min': 277.33},
#   'wind_speed': 3.5},
#  {'dt': 1643414400,
#   'humidity': 56.1,
#   'pressure': 1020.11,
#   'temp': {'average': 286.63,
#    'average_max': 290.9,
#    'average_min': 282.2,
#    'record_max': 294.15,
#    'record_min': 276.37},
#   'wind_speed': 3.09},
#  {'dt': 1643500800,
#   'humidity': 54.62,
#   'pressure': 1020.15,
#   'temp': {'average': 286.64,
#    'average_max': 291.59,
#    'average_min': 281.83,
#    'record_max': 295.15,
#    'record_min': 276.68},
#   'wind_speed': 3.3},
#  {'dt': 1643587200,
#   'humidity': 54.55,
#   'pressure': 1019.76,
#   'temp': {'average': 286.93,
#    'average_max': 291.79,
#    'average_min': 282.1,
#    'record_max': 296.67,
#    'record_min': 276.41},
#   'wind_speed': 3.79},
#  {'dt': 1643673600,
#   'humidity': 58.68,
#   'pressure': 1019.31,
#   'temp': {'average': 287.57,
#    'average_max': 293.1,
#    'average_min': 282.31,
#    'record_max': 300.15,
#    'record_min': 277.07},
#   'wind_speed': 3.67},
#  {'dt': 1643760000,
#   'humidity': 61.32,
#   'pressure': 1018.99,
#   'temp': {'average': 287.91,
#    'average_max': 293.16,
#    'average_min': 282.9,
#    'record_max': 300.12,
#    'record_min': 276.49},
#   'wind_speed': 3.78},
#  {'dt': 1643846400,
#   'humidity': 59.98,
#   'pressure': 1019.63,
#   'temp': {'average': 287.58,
#    'average_max': 293.21,
#    'average_min': 282.47,
#    'record_max': 299.98,
#    'record_min': 276.6},
#   'wind_speed': 3.82},
#  {'dt': 1643932800,
#   'humidity': 58.14,
#   'pressure': 1018.92,
#   'temp': {'average': 287.99,
#    'average_max': 294.01,
#    'average_min': 282.33,
#    'record_max': 301.15,
#    'record_min': 275.28},
#   'wind_speed': 3.28},
#  {'dt': 1644019200,
#   'humidity': 52.56,
#   'pressure': 1017.27,
#   'temp': {'average': 289.2,
#    'average_max': 294.64,
#    'average_min': 283.65,
#    'record_max': 301.15,
#    'record_min': 276.27},
#   'wind_speed': 3.9},
#  {'dt': 1644105600,
#   'humidity': 52.18,
#   'pressure': 1016.77,
#   'temp': {'average': 288.8,
#    'average_max': 293.9,
#    'average_min': 284.02,
#    'record_max': 300.15,
#    'record_min': 274.88},
#   'wind_speed': 4.09},
#  {'dt': 1644192000,
#   'humidity': 53.86,
#   'pressure': 1016.88,
#   'temp': {'average': 288.49,
#    'average_max': 293.5,
#    'average_min': 283.57,
#    'record_max': 302.15,
#    'record_min': 275.86},
#   'wind_speed': 4.98},
#  {'dt': 1644278400,
#   'humidity': 51.01,
#   'pressure': 1018.13,
#   'temp': {'average': 289.05,
#    'average_max': 294.29,
#    'average_min': 284.37,
#    'record_max': 303.15,
#    'record_min': 278.01},
#   'wind_speed': 3.42},
#  {'dt': 1644364800,
#   'humidity': 55.81,
#   'pressure': 1018.38,
#   'temp': {'average': 288.47,
#    'average_max': 293.64,
#    'average_min': 283.49,
#    'record_max': 303.15,
#    'record_min': 276.65},
#   'wind_speed': 3.34},
#  {'dt': 1644451200,
#   'humidity': 57.12,
#   'pressure': 1017.87,
#   'temp': {'average': 287.92,
#    'average_max': 293.01,
#    'average_min': 283.19,
#    'record_max': 305.15,
#    'record_min': 276.94},
#   'wind_speed': 3.86},
#  {'dt': 1644537600,
#   'humidity': 56.96,
#   'pressure': 1018.09,
#   'temp': {'average': 287.4,
#    'average_max': 292.69,
#    'average_min': 282.43,
#    'record_max': 299.15,
#    'record_min': 271.79},
#   'wind_speed': 4.26},
#  {'dt': 1644624000,
#   'humidity': 57.5,
#   'pressure': 1018.04,
#   'temp': {'average': 287.74,
#    'average_max': 293.38,
#    'average_min': 282.96,
#    'record_max': 299.15,
#    'record_min': 278.07},
#   'wind_speed': 3.76}]

# %%
#o dt
#o humidity
#o pressure
#o wind_speed
#o average
#o average_max
#o average_min
#o record_max
#o record_min

# %%
df = pd.DataFrame.from_dict(data=djson['list'])

# %%
df = pd.concat([df, pd.json_normalize(df['temp'])], axis=1)

# %%
del df['temp']
df
# Out:
#             dt  humidity  pressure  wind_speed  average  average_max  \
# 0   1642118400     59.90   1017.75        4.47   287.12       290.97
# 1   1642204800     63.27   1019.25        4.48   286.89       291.45
# 2   1642291200     57.76   1017.88        4.86   286.19       291.17
# 3   1642377600     60.96   1017.27        4.08   286.60       291.21
# 4   1642464000     59.32   1018.62        4.90   286.67       290.93
# 5   1642550400     63.17   1019.84        4.30   286.26       291.04
# 6   1642636800     58.39   1021.31        3.65   286.25       291.49
# 7   1642723200     54.07   1020.47        3.55   287.23       293.07
# 8   1642809600     53.70   1018.68        3.78   287.90       293.44
# 9   1642896000     55.81   1017.87        3.91   287.70       292.27
# 10  1642982400     56.60   1017.74        3.92   288.09       292.74
# 11  1643068800     57.74   1018.05        3.46   287.92       293.00
# 12  1643155200     54.63   1017.00        4.61   287.86       292.62
# 13  1643241600     56.83   1016.67        4.34   287.38       291.80
# 14  1643328000     55.14   1018.82        3.50   286.77       290.60
# 15  1643414400     56.10   1020.11        3.09   286.63       290.90
# 16  1643500800     54.62   1020.15        3.30   286.64       291.59
# 17  1643587200     54.55   1019.76        3.79   286.93       291.79
# 18  1643673600     58.68   1019.31        3.67   287.57       293.10
# 19  1643760000     61.32   1018.99        3.78   287.91       293.16
# 20  1643846400     59.98   1019.63        3.82   287.58       293.21
# 21  1643932800     58.14   1018.92        3.28   287.99       294.01
# 22  1644019200     52.56   1017.27        3.90   289.20       294.64
# 23  1644105600     52.18   1016.77        4.09   288.80       293.90
# 24  1644192000     53.86   1016.88        4.98   288.49       293.50
# 25  1644278400     51.01   1018.13        3.42   289.05       294.29
# 26  1644364800     55.81   1018.38        3.34   288.47       293.64
# 27  1644451200     57.12   1017.87        3.86   287.92       293.01
# 28  1644537600     56.96   1018.09        4.26   287.40       292.69
# 29  1644624000     57.50   1018.04        3.76   287.74       293.38
#
#     average_min  record_max  record_min
# 0        283.11      293.15      277.80
# 1        282.65      294.12      276.99
# 2        281.83      295.00      276.32
# 3        281.40      293.93      275.03
# 4        281.70      295.15      274.36
# 5        281.27      293.95      274.57
# 6        281.48      295.00      275.24
# 7        281.59      297.15      276.61
# 8        282.56      301.04      276.06
# 9        282.73      297.10      277.64
# 10       283.38      296.03      277.36
# 11       282.20      299.15      275.70
# 12       282.61      300.15      273.39
# 13       282.34      296.00      278.65
# 14       282.86      292.15      277.33
# 15       282.20      294.15      276.37
# 16       281.83      295.15      276.68
# 17       282.10      296.67      276.41
# 18       282.31      300.15      277.07
# 19       282.90      300.12      276.49
# 20       282.47      299.98      276.60
# 21       282.33      301.15      275.28
# 22       283.65      301.15      276.27
# 23       284.02      300.15      274.88
# 24       283.57      302.15      275.86
# 25       284.37      303.15      278.01
# 26       283.49      303.15      276.65
# 27       283.19      305.15      276.94
# 28       282.43      299.15      271.79
# 29       282.96      299.15      278.07
